# %% [markdown]
# ## Scrapping flipkart

# %%
# Importing required libraries

from bs4 import BeautifulSoup
import requests
import numpy as np

# %%
# For making the request to the website in disguise:

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"}

# %%
# Get the main page URL

url = "https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"

# %%
# Make request and check

html = requests.get(url)
html
# Out:
# <Response [200]>

# %% [markdown]
# #### Create the bs object for the main page

# %%
soup_main = BeautifulSoup(html.text,'lxml')
print(soup_main.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.5ffd15.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
laptops = soup_main.find_all(name='div',class_='_1AtVbE col-12-12')
len(laptops)
# Out:
# 30

# %%
# Slicincig the relevant data

laptops = laptops[2:-4]
len(laptops)
# Out:
# 24

# %% [markdown]
# #### Fetching the name of the first laptop

# %%
laptops[0].find(name='div',class_='_4rR01T').text
# Out:
# 'ASUS Chromebook Touch Intel Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) C523NA-A20303 Chro...'

# %%
soup_laptop.find(name='span',class_='B_NuCI').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 soup_laptop.find(name='span',class_='B_NuCI').text
#
# NameError: name 'soup_laptop' is not defined

# %% [markdown]
# #### Creating link to vist to the first laptop

# %%
# Fetching the 'href' value from anchor tag

laptops[0].a['href']
# Out:
# '/asus-chromebook-touch-intel-celeron-dual-core-4-gb-64-gb-emmc-storage-chrome-os-c523na-a20303/p/itm084aa0e5ae2b6?pid=COMG49CZ8SVW7TWD&lid=LSTCOMG49CZ8SVW7TWDMKMYIO&marketplace=FLIPKART&q=laptops&store=6bo%2Fb5g&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_Dx0mm6GRRZA1TN8RjuFa3knmNP2tbHqAPW67mTGDD976vPIvYohXcHoG3fL9qsXgt09MbqWXuZaP95vE30rMdw%3D%3D&ppt=None&ppn=None&ssid=yap16ozwu80000001691071123016&qH=c06ea84a1e3dc3c6'

# %%
url2 = "https://www.flipkart.com" + laptops[0].a['href']
url2
# Out:
# 'https://www.flipkart.com/asus-chromebook-touch-intel-celeron-dual-core-4-gb-64-gb-emmc-storage-chrome-os-c523na-a20303/p/itm084aa0e5ae2b6?pid=COMG49CZ8SVW7TWD&lid=LSTCOMG49CZ8SVW7TWDMKMYIO&marketplace=FLIPKART&q=laptops&store=6bo%2Fb5g&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_Dx0mm6GRRZA1TN8RjuFa3knmNP2tbHqAPW67mTGDD976vPIvYohXcHoG3fL9qsXgt09MbqWXuZaP95vE30rMdw%3D%3D&ppt=None&ppn=None&ssid=yap16ozwu80000001691071123016&qH=c06ea84a1e3dc3c6'

# %% [markdown]
# #### bs object for the product page

# %%
html2 = requests.get(url2).text
soup_laptop = BeautifulSoup(html2, 'lxml')
print(soup_laptop.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.5ffd15.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %% [markdown]
# #### Fetch the price of the laptop

# %%
soup_laptop.find(name='div', class_='_30jeq3 _16Jk6d').text
# Out:
# '₹18,990'

# %% [markdown]
# #### technical details table/Specifications object

# %%
specs = soup_laptop.find(name='div',class_='_3dtsli')
print(specs.prettify())
# Out:
# <div class="_3dtsli">
#  <div class="_5pFuey">
#   Specifications
#  </div>
#  <div>
#   <div class="_1UhVsV _3AsE0T">
#    <div class="_3k-BhJ">
#     <div class="flxcaE">
#      General
#     </div>
#     <table class="_14cfVK">
#      <tbody>
#       <tr class="_1s_Smc row">
#        <td class="_1hKmbr col col-3-12">
#         Sales Package
#        </td>
#        <td class="URwL2w col col-9-12">
#         <ul>
#          <li class="_21lJbe">
#           1N Laptop, 1N Charger, 1N User Manual
#          </li>
#         </ul>
#        </td>
#       </tr>
#       <tr class="_1s_Smc row">
#        <td class="_1hKmbr col col-3-12">
#         Model Number
#        </td>
#        <td class="URwL2w col col-9-12">
#         <ul>
#          <li class="_21lJbe">
#           4G
#          </li>
#         </ul>
#        </td>
#       </tr>
#       <tr class="_1s_Smc row">
#        <td class="_1hKmbr col col-3-12">
#         Part Number
#        </td>
#        <td class="URwL2w col col-9-12">
# ...

# %%
keys = []
for _ in specs.find_all(name='td',class_='_1hKmbr col col-3-12'):
    keys.append(_.text)
keys
# Out:
# ['Sales Package',
#  'Model Number',
#  'Part Number',
#  'Model Name',
#  'Series',
#  'Color',
#  'Type',
#  'Suitable For',
#  'Battery Backup',
#  'MS Office Provided',
#  'Processor Brand',
#  'Processor Name',
#  'SSD',
#  'RAM',
#  'RAM Type',
#  'EMMC Storage Capacity',
#  'Processor Variant',
#  'Clock Speed',
#  'Graphic Processor',
#  'Operating System',
#  'Supported Operating System',
#  'Mic In',
#  'USB Port',
#  'Touchscreen',
#  'Screen Size',
#  'Screen Resolution',
#  'Screen Type',
#  'Speakers',
#  'Wireless LAN',
#  'Bluetooth',
#  'Dimensions',
#  'Weight',
#  'Disk Drive',
#  'Web Camera',
#  'Keyboard',
#  'Backlit Keyboard',
#  'Warranty Summary',
#  'Warranty Service Type',
#  'Covered in Warranty',
#  'Not Covered in Warranty']

# %%
values = []
for _ in specs.find_all(name='td',class_='URwL2w col col-9-12'):
    values.append(_.text)
values
# Out:
# ['1N Laptop, 1N Charger, 1N User Manual',
#  '4G',
#  'PB4G11064#2767C',
#  'Primebook 4G',
#  '4G Android Based',
#  'Blue',
#  'Thin and Light Laptop',
#  'Processing & Multitasking, Learning',
#  'Upto 8 hours',
#  'No',
#  'MediaTek',
#  'MediaTek MT8788',
#  'No',
#  '4 GB',
#  'LPDDR4',
#  '64 GB',
#  'MT8788',
#  'Max Frequency Up to 2.0 GHz',
#  'MediaTek Integrated ARM Mali G72',
#  'Prime OS',
#  'Based on Android 11',
#  'Yes',
#  '1 x USB 2.0, 1 x USB 3.0',
#  'No',
#  '29.46 cm (11.6 Inch)',
#  '1366 x 768 Pixels',
#  'HD IPS',
#  'Built-in Speakers',
#  'Wifi 5GHz and 2.4 GHz',
#  'V5.0',
#  '281 X 192 X 19.3 mm',
#  '1.065 Kg',
#  'Not Available',
#  '2.0 MP',
#  'QWERTY with PrimeOS Special KB Shortcuts',
#  'No',
#  '1 Year Pick and Drop Warranty',
#  'Pick and Drop',
#  'Manufacturing Defects',
#  'Accidental Damage']

# %% [markdown]
# #### Creating dictionary of fetch data from the table

# %%
d_primebook = {}
for i in range(len(keys)):
    d_primebook[keys[i]] = values[i]

# %%
d_primebook
# Out:
# {'Sales Package': '1N Laptop, 1N Charger, 1N User Manual',
#  'Model Number': '4G',
#  'Part Number': 'PB4G11064#2767C',
#  'Model Name': 'Primebook 4G',
#  'Series': '4G Android Based',
#  'Color': 'Blue',
#  'Type': 'Thin and Light Laptop',
#  'Suitable For': 'Processing & Multitasking, Learning',
#  'Battery Backup': 'Upto 8 hours',
#  'MS Office Provided': 'No',
#  'Processor Brand': 'MediaTek',
#  'Processor Name': 'MediaTek MT8788',
#  'SSD': 'No',
#  'RAM': '4 GB',
#  'RAM Type': 'LPDDR4',
#  'EMMC Storage Capacity': '64 GB',
#  'Processor Variant': 'MT8788',
#  'Clock Speed': 'Max Frequency Up to 2.0 GHz',
#  'Graphic Processor': 'MediaTek Integrated ARM Mali G72',
#  'Operating System': 'Prime OS',
#  'Supported Operating System': 'Based on Android 11',
#  'Mic In': 'Yes',
#  'USB Port': '1 x USB 2.0, 1 x USB 3.0',
#  'Touchscreen': 'No',
#  'Screen Size': '29.46 cm (11.6 Inch)',
#  'Screen Resolution': '1366 x 768 Pixels',
#  'Screen Type': 'HD IPS',
# ...

# %% [markdown]
# ---
# ## Generalizing (prototype)
# 1. Available pages: 41

# %%
lst_data = []
for page in range(1,2):
    main_page_url = f"https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={page}"
    html_main = requests.get(main_page_url).text
    soup_main = BeautifulSoup(html_main, 'lxml')
    
    # Finding all the scetions containing laptops on the present page (~30)
    laptops = soup_main.find_all(name='div',class_='_1AtVbE col-12-12')
    
    # Slicing the relevant data (len(laptops)~24)
    laptops = laptops[2:-4]

    # Creating laptop_urls from the present page
    laptop_urls = []
    for i in laptops:
        url = "https://www.flipkart.com"+i.a['href']
        laptop_urls.append(url)
        
    # Scrapping the specifications 
    for url in laptop_urls:
        data = {}
        html_prod = requests.get(url).text
        soup_laptop = BeautifulSoup(html_prod, 'lxml')
    
        # Fetching the name of the laptop
        name = soup_laptop.find(name='span',class_='B_NuCI').text
        data['name'] = name
        
        # Finding the specification/specs section
        specs = soup_laptop.find(name='div',class_='_3dtsli')

        # Collecting the attributes
        keys = []
        for _ in specs.find_all(name='td',class_='_1hKmbr col col-3-12'):
            keys.append(_.text)

        # Collecting the records for the corresponding attributes
        values = []
        for _ in specs.find_all(name='td',class_='URwL2w col col-9-12'):
            values.append(_.text)

        # Adding the collected info to data
        for i in range(len(keys)):
            data[keys[i]] = values[i]
    
        lst_data.append(data)

# %% [markdown]
# ---
# ## Below code is the required scrapping code for flipkart

# %%
def keys_lower_inplace(input_dict):
    for key in list(input_dict.keys()):
        new_key = key.lower()
        if new_key != key:
            input_dict[new_key] = input_dict.pop(key)

# %%
import requests
from bs4 import BeautifulSoup
import time
import logging

# Logging
logging.basicConfig(filename='scraping.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to convert dictionary keys to lowercase
def keys_lower_inplace(data):
    for key in list(data.keys()):
        data[key.lower()] = data.pop(key)

# Series to hold the scrpped data
all_data = []

begin = time.perf_counter()
for page in range(1, 42):
    try:
        # Start the counter
        logging.info(f"Page {page} scraping started...")
        
        print("**************************************************\n")
        print(f"Page {page} scrapping started...")
        start = time.perf_counter()

        # Fetch the HTML and create soup object for the main page
        main_page_url = f"https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={page}"
        html_main = requests.get(main_page_url).text
        soup_main = BeautifulSoup(html_main, 'lxml')

        # Finding all the anchor tags of boxes containing laptops on the present page (#laptops=24)
        laptops = soup_main.find_all(name='a', class_='_1fQZEK')

        # Collecting laptop_urls from the present page
        laptop_urls = []
        for i in laptops:
            try:
                url = "https://www.flipkart.com" + i['href']
            except Exception as e:
                logging.error(f"Error while collecting laptop URL: {e}")
            else:
                laptop_urls.append(url)

        # Scrapping the specifications for the laptops on the present page
        for url in laptop_urls:
            data = {}
            try:
                html_prod = requests.get(url).text
                soup_laptop = BeautifulSoup(html_prod, 'lxml')

                # Fetching the name of the laptop
                name = soup_laptop.find(name='span', class_='B_NuCI').text
                data['name'] = name

                # Fetch the price of the laptop
                price = soup_laptop.find(name='div', class_='_30jeq3 _16Jk6d').text
                data['price'] = price

                # Finding the specification/specs section
                specs = soup_laptop.find(name='div', class_='_3dtsli')

                # Collecting the attributes
                keys = [_.text for _ in specs.find_all(name='td', class_='_1hKmbr col col-3-12')]

                # Collecting the records for the corresponding attributes
                values = [_.text for _ in specs.find_all(name='td', class_='URwL2w col col-9-12')]

                # Adding the collected info to data
                for i in range(len(keys)):
                    data[keys[i]] = values[i]

                # Convert the keys of the dictionary to lowercase
                keys_lower_inplace(data)

                # Append the data from the present page in the list
                all_data.append(data)
            except Exception as e:
                logging.error(f"Error while scraping laptop page data: {e}")
        
        # Wait for a few seconds
        end = time.perf_counter()
        logging.info(f"Execution finished for page {page}. Execution time: {end - start} seconds.")
        logging.info("Sleeping for 7 seconds...")
        print(f"Execution finished for page {page}\nExecution time to scrape page {1}: {end-start}\n")
        print("Sleeping for 7 seconds...")
        time.sleep(7)

    except Exception as e:
        logging.error(f"Error occurred during main page {page} scraping: {e}")

terminate = time.perf_counter()
logging.info(f"Finished Scraping in {terminate-begin}")
print("\nFinished Scrapping\n")
print(f"Total execution time of the script: {terminate-begin}")
# Out:
# **************************************************
#
# Page 1 scrapping started...
# Execution finished for page 1
# Execution time to scrape page 1: 57.8108466998674
#
# Sleeping for 3 seconds...
#
# Finished Scrapping
#
# Total execution time of the script: -60.814279899932444

# %%
sr = 1
for i in all_data:
    print(f"{sr}: {i['name']}")
    print()
    sr+=1
# Out:
# 1: Primebook 4G Android Based MediaTek MT8788 - (4 GB/64 GB EMMC Storage/Prime OS) 4G Thin and Light Laptop  (11.6 Inch, Blue, 1.065 Kg)
#
# 2: Primebook 4G enabled Android based MediaTek MT8788 - (4 GB/128 GB EMMC Storage/Prime OS) S 4G Thin and Light Laptop  (11 Inch, Indigo Blue, 1.065 Kg)
#
# 3: HP 15s (2023) Athlon Dual Core 3050U - (8 GB/512 GB SSD/Windows 11 Home) 15s-ey1509AU Thin and Light Laptop  (15.6 Inch, Natural Silver, 1.69 Kg, With MS Office)
#
# 4: Lenovo V15 Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) V15 G2 ALC Thin and Light Laptop  (15.6 Inch, Black, 1.7 Kg)
#
# 5: HP 15s (2023) Ryzen 3 Dual Core 3250U - (8 GB/512 GB SSD/Windows 11 Home) 15s- eq1580AU Thin and Light Laptop  (15.6 Inch, Natural Silver, 1.69 Kg, With MS Office)
#
# 6: ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS | X515EA-EJ328WS Thin and Light Laptop  (15.6 Inch, Transparent Silver, 1.80 kg, With MS Office)
#
# ...

# %% [markdown]
# ---
# ### ----------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Scrapping Smartprix.com

# %%
sp_url = "https://www.smartprix.com/laptops"

main_html = requests.get(sp_url, headers)
main_html
# Out:
# <Response [200]>

# %% [markdown]
# #### soup1 object for traversing the laptop boxes

# %%
soup1 = BeautifulSoup(main_html.text, 'lxml')
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html class="way-item-finder" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    Laptops Price List in India | Smartprix
#   </title>
#   <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="#4692F0" name="theme-color"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="171761809591603" property="fb:app_id"/>
#   <meta content="max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <link href="https://www.smartprix.com/laptops" rel="canonical"/>
#   <meta content="Smartprix" property="og:site_name"/>
#   <meta content="@smartprix" name="twitter:site"/>
#   <meta content="@smartprix" name="twitter:creator"/>
#   <meta content="summary" name="twitter:card"/>
# ...

# %% [markdown]
# #### Fetching the link of the first laptop

# %%
soup1.find(name='div', class_='sm-product has-tag has-features has-actions').a.h2.text
# Out:
# 'HP 15s-fr2515TU Laptop (11th Gen Core i3/ 8GB/ 512GB SSD/ Win11)'

# %%
len(soup1.find_all(name='div', class_='sm-product has-tag has-features has-actions'))
# Out:
# 20

# %% [raw]
# To find the most occurring attributes in the specification table of all the laptops from Flipkart.com
#
#
# import requests
# from bs4 import BeautifulSoup
# from collections import Counter
#
# # List of laptop URLs to scrape
# #laptop_urls = soup_main.find_all() [
#     #"https://www.flipkart.com/laptop-1",
#     #"https://www.flipkart.com/laptop-2",
#     # Add more URLs here
#
#
# # Initialize a list to store attribute names
# attributes = []
#
# # Loop through laptop URLs and extract attributes
# for url in laptops_urls:
#     response = requests.get(url)
#     soup = BeautifulSoup(response.content, "lxml")
#
#     # Locate the specification table and extract attributes
#     table = soup.find("table")
#     if table:
#         rows = table.find_all("tr")
#         for row in rows:
#             columns = row.find_all("td")
#             if len(columns) == 2:  # Assuming each row has two columns: attribute name and value
#                 attribute = columns[0].get_text(strip=True)
#                 attributes.append(attribute)
#
# # Count the occurrences of each attribute
# attribute_counts = Counter(attributes)
#
# # Find the most common attributes
# most_common_attributes = attribute_counts.most_common()
#
# # Print the most common attributes and their occurrence counts
# for attribute, count in most_common_attributes:
#     print(f"{attribute}: {count}")
