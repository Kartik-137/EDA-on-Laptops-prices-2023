# %%
import requests
from bs4 import BeautifulSoup
import time
import logging

# Logging
logging.basicConfig(filename='scraping.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to convert dictionary keys to lowercase
def keys_lower_inplace(data):
    for key in list(data.keys()):
        data[key.lower()] = data.pop(key)

# List to hold the scrpped data
all_data = []

begin = time.perf_counter()
for page in range(1, 42):
    try:
        # Start the counter
        logging.info(f"Page {page} scraping started...")
        
        print("**************************************************\n")
        print(f"Page {page} scrapping started...")
        start = time.perf_counter()

        # Fetch the HTML and create soup object for the main page
        main_page_url = f"https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={page}"
        html_main = requests.get(main_page_url).text
        soup_main = BeautifulSoup(html_main, 'lxml')

        # Finding all the anchor tags of boxes containing laptops on the present page (#laptops=24)
        laptops = soup_main.find_all(name='a', class_='_1fQZEK')

        # Collecting laptop_urls from the present page
        laptop_urls = []
        for i in laptops:
            try:
                url = "https://www.flipkart.com" + i['href']
            except Exception as e:
                logging.error(f"Error while collecting laptop URL: {e}")
            else:
                laptop_urls.append(url)

        # Scrapping the specifications for the laptops on the present page
        for url in laptop_urls:
            data = {}
            try:
                html_prod = requests.get(url).text
                soup_laptop = BeautifulSoup(html_prod, 'lxml')

                # Fetching the name of the laptop
                name = soup_laptop.find(name='span', class_='B_NuCI').text
                data['name'] = name

                # Fetch the price of the laptop
                price = soup_laptop.find(name='div', class_='_30jeq3 _16Jk6d').text
                data['price'] = price

                # Finding the specification/specs section
                specs = soup_laptop.find(name='div', class_='_3dtsli')

                # Collecting the attributes
                keys = [_.text for _ in specs.find_all(name='td', class_='_1hKmbr col col-3-12')]

                # Collecting the records for the corresponding attributes
                values = [_.text for _ in specs.find_all(name='td', class_='URwL2w col col-9-12')]

                # Adding the collected info to data
                for i in range(len(keys)):
                    data[keys[i]] = values[i]

                # Convert the keys of the dictionary to lowercase
                keys_lower_inplace(data)

                # Append the data from the present page in the list
                all_data.append(data)
            except Exception as e:
                logging.error(f"Error while scraping laptop page data: {e}")
        
        # Wait for a few seconds
        end = time.perf_counter()
        logging.info(f"Execution finished for page {page}. Execution time: {end - start} seconds.")
        logging.info("Sleeping for 7 seconds...")
        print(f"Execution finished for page {page}\nExecution time to scrape page {1}: {end-start}\n")
        print("Sleeping for 7 seconds...")
        time.sleep(7)

    except Exception as e:
        logging.error(f"Error occurred during main page {page} scraping: {e}")

terminate = time.perf_counter()
logging.info(f"Finished Scraping in {terminate-begin}")
print("\nFinished Scrapping\n")
print(f"Total execution time of the script: {terminate-begin}")
# Out:
# **************************************************
#
# Page 1 scrapping started...
# Execution finished for page 1
# Execution time to scrape page 1: 16.522067956626415
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 2 scrapping started...
# Execution finished for page 2
# Execution time to scrape page 1: 17.54845768213272
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 3 scrapping started...
# Execution finished for page 3
# Execution time to scrape page 1: 17.554554220288992
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 4 scrapping started...
# Execution finished for page 4
# Execution time to scrape page 1: 17.107618141919374
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 5 scrapping started...
# Execution finished for page 5
# Execution time to scrape page 1: 16.202299371361732
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 6 scrapping started...
# Execution finished for page 6
# Execution time to scrape page 1: 16.101793237030506
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 7 scrapping started...
# Execution finished for page 7
# Execution time to scrape page 1: 17.186868220567703
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 8 scrapping started...
# Execution finished for page 8
# Execution time to scrape page 1: 16.237785812467337
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 9 scrapping started...
# Execution finished for page 9
# Execution time to scrape page 1: 16.41758009046316
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 10 scrapping started...
# Execution finished for page 10
# Execution time to scrape page 1: 16.173333786427975
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 11 scrapping started...
# Execution finished for page 11
# Execution time to scrape page 1: 16.557823333889246
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 12 scrapping started...
# Execution finished for page 12
# Execution time to scrape page 1: 15.637523282319307
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 13 scrapping started...
# Execution finished for page 13
# Execution time to scrape page 1: 15.853077575564384
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 14 scrapping started...
# Execution finished for page 14
# Execution time to scrape page 1: 15.24757256731391
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 15 scrapping started...
# Execution finished for page 15
# Execution time to scrape page 1: 16.36175660789013
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 16 scrapping started...
# Execution finished for page 16
# Execution time to scrape page 1: 15.12287413328886
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 17 scrapping started...
# Execution finished for page 17
# Execution time to scrape page 1: 16.03003591671586
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 18 scrapping started...
# Execution finished for page 18
# Execution time to scrape page 1: 15.830949269235134
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 19 scrapping started...
# Execution finished for page 19
# Execution time to scrape page 1: 15.31974982097745
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 20 scrapping started...
# Execution finished for page 20
# Execution time to scrape page 1: 17.94710538163781
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 21 scrapping started...
# Execution finished for page 21
# Execution time to scrape page 1: 15.836838476359844
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 22 scrapping started...
# Execution finished for page 22
# Execution time to scrape page 1: 15.544129617512226
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 23 scrapping started...
# Execution finished for page 23
# Execution time to scrape page 1: 14.973947905004025
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 24 scrapping started...
# Execution finished for page 24
# Execution time to scrape page 1: 15.728233579546213
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 25 scrapping started...
# Execution finished for page 25
# Execution time to scrape page 1: 15.445590227842331
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 26 scrapping started...
# Execution finished for page 26
# Execution time to scrape page 1: 15.016879685223103
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 27 scrapping started...
# Execution finished for page 27
# Execution time to scrape page 1: 16.203846599906683
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 28 scrapping started...
# Execution finished for page 28
# Execution time to scrape page 1: 16.454084485769272
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 29 scrapping started...
# Execution finished for page 29
# Execution time to scrape page 1: 14.43796207010746
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 30 scrapping started...
# Execution finished for page 30
# Execution time to scrape page 1: 14.981162585318089
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 31 scrapping started...
# Execution finished for page 31
# Execution time to scrape page 1: 14.756701596081257
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 32 scrapping started...
# Execution finished for page 32
# Execution time to scrape page 1: 18.54958736151457
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 33 scrapping started...
# Execution finished for page 33
# Execution time to scrape page 1: 16.002562932670116
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 34 scrapping started...
# Execution finished for page 34
# Execution time to scrape page 1: 17.0578140206635
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 35 scrapping started...
# Execution finished for page 35
# Execution time to scrape page 1: 15.102130752056837
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 36 scrapping started...
# Execution finished for page 36
# Execution time to scrape page 1: 16.4954448454082
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 37 scrapping started...
# Execution finished for page 37
# Execution time to scrape page 1: 15.443318251520395
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 38 scrapping started...
# Execution finished for page 38
# Execution time to scrape page 1: 16.34653165563941
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 39 scrapping started...
# Execution finished for page 39
# Execution time to scrape page 1: 15.952751237899065
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 40 scrapping started...
# Execution finished for page 40
# Execution time to scrape page 1: 15.900644969195127
#
# Sleeping for 7 seconds...
# **************************************************
#
# Page 41 scrapping started...
# Execution finished for page 41
# Execution time to scrape page 1: 16.686104107648134
#
# Sleeping for 7 seconds...
#
# Finished Scrapping
#
# Total execution time of the script: 947.1711446531117

# %% [markdown]
# ---
# ### Exporting the data to a JSON file

# %%
import json
with open('laptops.json','w') as file:
    json.dump(all_data,file,indent=4)

# %% [markdown]
# ---
# ### Creating the DataFrame

# %%
# Load the JSON file

import json
with open('laptops.json','r') as file:
    data = json.load(file)

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
# {'name': 'ASUS Chromebook Touch Intel Celeron Dual Core - (4 GB/64 GB EMMC Storage/Chrome OS) C523NA-A20303 Chromebook\xa0\xa0(15.6 inch, Silver, 1.69 Kg)',
#  'price': '₹18,990',
#  'sales package': 'Laptop, Power Adaptor, User Guide',
#  'model number': 'C523NA-A20303',
#  'part number': '90NX01R1-M05250 | 90NX01R1-M03520',
#  'series': 'Chromebook Touch Intel',
#  'color': 'Silver',
#  'type': 'Chromebook',
#  'suitable for': 'Processing & Multitasking',
#  'power supply': '45W AC Adapter',
#  'battery cell': '2 Cell',
#  'ms office provided': 'No',
#  'processor brand': 'Intel',
#  'processor name': 'Celeron Dual Core',
#  'ssd': 'No',
#  'ram': '4 GB',
#  'ram type': 'LPDDR4',
#  'emmc storage capacity': '64 GB',
#  'processor variant': 'N3350',
#  'chipset': 'NA',
#  'clock speed': '1.1 GHz with Turbo Boost Upto 2.4 GHz',
#  'cache': '2',
#  'graphic processor': 'Intel Integrated HD 500',
#  'number of cores': '2',
#  'operating system': 'Chrome',
#  'mic in': 'Yes',
#  'usb port': '2 x USB 3.2 Gen 1 Type-A, 2 x USB 3.2 Gen 1 Type-C Support Display / Power Delivery',
#  'multi card slot': 'Micro SD Card Reader',
#  'touchscreen': 'Yes',
#  'screen size': '39.62 cm (15.6 inch)',
#  'screen resolution': '1920 x 1080 Pixels',
#  'screen type': 'Full HD LED Backlit LCD Glossy Display (16:9, NTSC: 45% Color Gamut, 200nits Brightness, 80% Screen-to-body Ratio)',
#  'speakers': 'Built-in Speaker',
#  'internal mic': 'Built-in Microphone',
#  'wireless lan': 'Wi-Fi 5 (802.11ac) Dual band (2*2)',
#  'bluetooth': 'v4.0',
#  'dimensions': '358 x 248 x 16.1',
#  'weight': '1.69 Kg',
#  'disk drive': 'Not Available',
#  'web camera': '720p HD Webcam',
#  'finger print sensor': 'No',
#  'security chip': 'Titan C Security Chip',
#  'keyboard': 'Chiclet Keyboard',
#  'backlit keyboard': 'No',
#  'pointer device': 'Touchpad',
#  'additional features': 'Google Assistant Voice-recognition Support, TYPE-C, 45W AC Adapter, Output: 15V DC, 3A, 45W, Input: 100~240V AC 50/60Hz Universal',
#  'warranty summary': '1 Year Onsite Warranty',
#  'warranty service type': 'Onsite',
#  'covered in warranty': 'Manufacturing Defects',
#  'not covered in warranty': 'Physical Damage',
#  'domestic warranty': '1 Year'}

# %% [markdown]
# #### Defining the required attributes and creating the DataFrame

# %%
attr = ['name', 'price', 'type', 'processor brand', 'processor name', 'processor generation', 'ssd', 'ssd capacity',\
        'hdd capacity', 'emmc storage capacity', 'ram', 'clock speed', 'graphic processor', 'operating system',\
        'touchscreen', 'screen size', 'screen resolution', 'screen type', 'weight', 'finger print sensor', 'backlit keyboard'
       ]

# %%
# Define all the empty list 

name_lst = []
price_lst = []
type_lst = []
processor_brand_lst = []
processor_name_lst = []
processor_gen_lst = []
ssd_lst = []
ssd_cap_lst = []
hdd_cap_lst = []
emmc_lst = []
ram_lst = []
clk_speed_lst = []
gpu_lst = []
os_lst = []
touchscreen_lst = []
screen_size_lst = []
screen_res_lst = []
screen_type_lst = []
weight_lst = []
fp_sensor_lst = []
key_light_lst = []

# %%
# Filling all the lists
import time
import numpy as np

start = time.perf_counter()
s = 1
for d in data:
    begin = time.perf_counter()
    print("*******************************\n")
    print(f"filling data of laptop no. {s}")
    
    # Start appending
    name_lst.append(d.get('name', np.nan))
    price_lst.append(d.get('price', np.nan))
    type_lst.append(d.get('type', np.nan))
    processor_brand_lst.append(d.get('processor brand', np.nan))
    processor_name_lst.append(d.get('processor name', np.nan))
    processor_gen_lst.append(d.get('processor generation', np.nan))
    ssd_lst.append(d.get('ssd', 'No'))
    ssd_cap_lst.append(d.get('ssd capacity', 0))
    hdd_cap_lst.append(d.get('hdd capacity', 0))
    emmc_lst.append(d.get('emmc storage capacity', 0))
    ram_lst.append(d.get('ram', 0))
    clk_speed_lst.append(d.get('clock speed', np.nan))
    gpu_lst.append(d.get('graphic processor', np.nan))
    os_lst.append(d.get('operating system', np.nan))
    touchscreen_lst.append(d.get('touchscreen', 'No'))
    screen_size_lst.append(d.get('screen size', np.nan))
    screen_res_lst.append(d.get('screen resolution', np.nan))
    screen_type_lst.append(d.get('screen type', np.nan))
    weight_lst.append(d.get('weight', np.nan))
    fp_sensor_lst.append(d.get('finger print sensor', 'No'))
    key_light_lst.append(d.get('backlit keyboard', 'No'))
    
    # Display the counter and sleep
    terminate = time.perf_counter()
    print(f"Finished filling in: {terminate-begin}")
    #print("Sleeping for 1 seconds...")
    s+=1
    #time.sleep(1)
    
print(f"Script executed in {time.perf_counter()-start}")
# Out:
# *******************************
#
# filling data of laptop no. 1
# Finished filling in: 5.539999983739108e-05
# *******************************
#
# filling data of laptop no. 2
# Finished filling in: 8.7999999323074e-06
# *******************************
#
# filling data of laptop no. 3
# Finished filling in: 7.60000011723605e-06
# *******************************
#
# filling data of laptop no. 4
# Finished filling in: 8.199999911084888e-06
# *******************************
#
# filling data of laptop no. 5
# Finished filling in: 4.229999990457145e-05
# *******************************
#
# filling data of laptop no. 6
# Finished filling in: 7.500000037907739e-06
# *******************************
#
# filling data of laptop no. 7
# Finished filling in: 7.000000096013537e-06
# *******************************
#
# filling data of laptop no. 8
# Finished filling in: 6.900000016685226e-06
# *******************************
#
# filling data of laptop no. 9
# Finished filling in: 7.599999889862374e-06
# *******************************
#
# filling data of laptop no. 10
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 11
# Finished filling in: 6.399999847417348e-06
# *******************************
#
# filling data of laptop no. 12
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 13
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 14
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 15
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 16
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 17
# Finished filling in: 7.3999999585794285e-06
# *******************************
#
# filling data of laptop no. 18
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 19
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 20
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 21
# Finished filling in: 6.499999926745659e-06
# *******************************
#
# filling data of laptop no. 22
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 23
# Finished filling in: 6.600000006073969e-06
# *******************************
#
# filling data of laptop no. 24
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 25
# Finished filling in: 1.160000010713702e-05
# *******************************
#
# filling data of laptop no. 26
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 27
# Finished filling in: 6.399999847417348e-06
# *******************************
#
# filling data of laptop no. 28
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 29
# Finished filling in: 6.600000006073969e-06
# *******************************
#
# filling data of laptop no. 30
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 31
# Finished filling in: 6.500000154119334e-06
# *******************************
#
# filling data of laptop no. 32
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 33
# Finished filling in: 8.900000011635711e-06
# *******************************
#
# filling data of laptop no. 34
# Finished filling in: 6.799999937356915e-06
# *******************************
#
# filling data of laptop no. 35
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 36
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 37
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 38
# Finished filling in: 6.699999858028605e-06
# *******************************
#
# filling data of laptop no. 39
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 40
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 41
# Finished filling in: 9.099999942918657e-06
# *******************************
#
# filling data of laptop no. 42
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 43
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 44
# Finished filling in: 6.0999998368060915e-06
# *******************************
#
# filling data of laptop no. 45
# Finished filling in: 6.799999937356915e-06
# *******************************
#
# filling data of laptop no. 46
# Finished filling in: 6.399999847417348e-06
# *******************************
#
# filling data of laptop no. 47
# Finished filling in: 6.0999998368060915e-06
# *******************************
#
# filling data of laptop no. 48
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 49
# Finished filling in: 6.499999926745659e-06
# *******************************
#
# filling data of laptop no. 50
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 51
# Finished filling in: 6.600000006073969e-06
# *******************************
#
# filling data of laptop no. 52
# Finished filling in: 6.900000016685226e-06
# *******************************
#
# filling data of laptop no. 53
# Finished filling in: 1.1299999869152089e-05
# *******************************
#
# filling data of laptop no. 54
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 55
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 56
# Finished filling in: 6.900000016685226e-06
# *******************************
#
# filling data of laptop no. 57
# Finished filling in: 6.399999847417348e-06
# *******************************
#
# filling data of laptop no. 58
# Finished filling in: 6.399999847417348e-06
# *******************************
#
# filling data of laptop no. 59
# Finished filling in: 6.399999847417348e-06
# *******************************
#
# filling data of laptop no. 60
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 61
# Finished filling in: 6.0999998368060915e-06
# *******************************
#
# filling data of laptop no. 62
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 63
# Finished filling in: 6.600000006073969e-06
# *******************************
#
# filling data of laptop no. 64
# Finished filling in: 6.0999998368060915e-06
# *******************************
#
# filling data of laptop no. 65
# Finished filling in: 1.2100000049031223e-05
# *******************************
#
# filling data of laptop no. 66
# Finished filling in: 6.200000143508078e-06
# *******************************
#
# filling data of laptop no. 67
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 68
# Finished filling in: 6.200000143508078e-06
# *******************************
#
# filling data of laptop no. 69
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 70
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 71
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 72
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 73
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 74
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 75
# Finished filling in: 2.2299999955066596e-05
# *******************************
#
# filling data of laptop no. 76
# Finished filling in: 6.499999926745659e-06
# *******************************
#
# filling data of laptop no. 77
# Finished filling in: 1.2399999832268804e-05
# *******************************
#
# filling data of laptop no. 78
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 79
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 80
# Finished filling in: 6.0999998368060915e-06
# *******************************
#
# filling data of laptop no. 81
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 82
# Finished filling in: 6.200000143508078e-06
# *******************************
#
# filling data of laptop no. 83
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 84
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 85
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 86
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 87
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 88
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 89
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 90
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 91
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 92
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 93
# Finished filling in: 1.1099999937869143e-05
# *******************************
#
# filling data of laptop no. 94
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 95
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 96
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 97
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 98
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 99
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 100
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 101
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 102
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 103
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 104
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 105
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 106
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 107
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 108
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 109
# Finished filling in: 1.0299999985363684e-05
# *******************************
#
# filling data of laptop no. 110
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 111
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 112
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 113
# Finished filling in: 6.70000008540228e-06
# *******************************
#
# filling data of laptop no. 114
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 115
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 116
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 117
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 118
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 119
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 120
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 121
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 122
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 123
# Finished filling in: 2.8500000098574674e-05
# *******************************
#
# filling data of laptop no. 124
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 125
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 126
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 127
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 128
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 129
# Finished filling in: 2.2800000124334474e-05
# *******************************
#
# filling data of laptop no. 130
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 131
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 132
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 133
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 134
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 135
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 136
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 137
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 138
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 139
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 140
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 141
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 142
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 143
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 144
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 145
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 146
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 147
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 148
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 149
# Finished filling in: 1.3800000033370452e-05
# *******************************
#
# filling data of laptop no. 150
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 151
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 152
# Finished filling in: 1.160000010713702e-05
# *******************************
#
# filling data of laptop no. 153
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 154
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 155
# Finished filling in: 5.000000101063051e-06
# *******************************
#
# filling data of laptop no. 156
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 157
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 158
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 159
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 160
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 161
# Finished filling in: 5.100000180391362e-06
# *******************************
#
# filling data of laptop no. 162
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 163
# Finished filling in: 6.799999937356915e-06
# *******************************
#
# filling data of laptop no. 164
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 165
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 166
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 167
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 168
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 169
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 170
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 171
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 172
# Finished filling in: 5.100000180391362e-06
# *******************************
#
# filling data of laptop no. 173
# Finished filling in: 1.13999999484804e-05
# *******************************
#
# filling data of laptop no. 174
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 175
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 176
# Finished filling in: 2.0300000187489786e-05
# *******************************
#
# filling data of laptop no. 177
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 178
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 179
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 180
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 181
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 182
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 183
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 184
# Finished filling in: 8.7999999323074e-06
# *******************************
#
# filling data of laptop no. 185
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 186
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 187
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 188
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 189
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 190
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 191
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 192
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 193
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 194
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 195
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 196
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 197
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 198
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 199
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 200
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 201
# Finished filling in: 1.250000013897079e-05
# *******************************
#
# filling data of laptop no. 202
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 203
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 204
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 205
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 206
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 207
# Finished filling in: 4.999999873689376e-06
# *******************************
#
# filling data of laptop no. 208
# Finished filling in: 7.999999979801942e-06
# *******************************
#
# filling data of laptop no. 209
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 210
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 211
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 212
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 213
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 214
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 215
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 216
# Finished filling in: 4.900000021734741e-06
# *******************************
#
# filling data of laptop no. 217
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 218
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 219
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 220
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 221
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 222
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 223
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 224
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 225
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 226
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 227
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 228
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 229
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 230
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 231
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 232
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 233
# Finished filling in: 1.1999999969702912e-05
# *******************************
#
# filling data of laptop no. 234
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 235
# Finished filling in: 7.899999900473631e-06
# *******************************
#
# filling data of laptop no. 236
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 237
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 238
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 239
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 240
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 241
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 242
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 243
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 244
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 245
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 246
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 247
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 248
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 249
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 250
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 251
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 252
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 253
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 254
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 255
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 256
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 257
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 258
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 259
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 260
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 261
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 262
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 263
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 264
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 265
# Finished filling in: 1.1100000165242818e-05
# *******************************
#
# filling data of laptop no. 266
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 267
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 268
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 269
# Finished filling in: 1.619999989088683e-05
# *******************************
#
# filling data of laptop no. 270
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 271
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 272
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 273
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 274
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 275
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 276
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 277
# Finished filling in: 6.300000222836388e-06
# *******************************
#
# filling data of laptop no. 278
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 279
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 280
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 281
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 282
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 283
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 284
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 285
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 286
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 287
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 288
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 289
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 290
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 291
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 292
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 293
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 294
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 295
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 296
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 297
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 298
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 299
# Finished filling in: 8.999999863590347e-06
# *******************************
#
# filling data of laptop no. 300
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 301
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 302
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 303
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 304
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 305
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 306
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 307
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 308
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 309
# Finished filling in: 1.3999999964653398e-05
# *******************************
#
# filling data of laptop no. 310
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 311
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 312
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 313
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 314
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 315
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 316
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 317
# Finished filling in: 6.299999995462713e-06
# *******************************
#
# filling data of laptop no. 318
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 319
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 320
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 321
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 322
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 323
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 324
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 325
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 326
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 327
# Finished filling in: 6.0999998368060915e-06
# *******************************
#
# filling data of laptop no. 328
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 329
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 330
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 331
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 332
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 333
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 334
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 335
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 336
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 337
# Finished filling in: 8.100000059130252e-06
# *******************************
#
# filling data of laptop no. 338
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 339
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 340
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 341
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 342
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 343
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 344
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 345
# Finished filling in: 6.4000000747910235e-06
# *******************************
#
# filling data of laptop no. 346
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 347
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 348
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 349
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 350
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 351
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 352
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 353
# Finished filling in: 1.4799999917158857e-05
# *******************************
#
# filling data of laptop no. 354
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 355
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 356
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 357
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 358
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 359
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 360
# Finished filling in: 7.099999947968172e-06
# *******************************
#
# filling data of laptop no. 361
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 362
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 363
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 364
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 365
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 366
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 367
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 368
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 369
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 370
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 371
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 372
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 373
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 374
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 375
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 376
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 377
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 378
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 379
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 380
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 381
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 382
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 383
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 384
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 385
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 386
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 387
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 388
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 389
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 390
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 391
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 392
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 393
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 394
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 395
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 396
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 397
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 398
# Finished filling in: 0.00028250000013940735
# *******************************
#
# filling data of laptop no. 399
# Finished filling in: 1.3600000102087506e-05
# *******************************
#
# filling data of laptop no. 400
# Finished filling in: 1.3200000012147939e-05
# *******************************
#
# filling data of laptop no. 401
# Finished filling in: 4.350000017439015e-05
# *******************************
#
# filling data of laptop no. 402
# Finished filling in: 3.450000008342613e-05
# *******************************
#
# filling data of laptop no. 403
# Finished filling in: 1.3099999932819628e-05
# *******************************
#
# filling data of laptop no. 404
# Finished filling in: 1.3099999932819628e-05
# *******************************
#
# filling data of laptop no. 405
# Finished filling in: 1.2399999832268804e-05
# *******************************
#
# filling data of laptop no. 406
# Finished filling in: 1.2700000070253736e-05
# *******************************
#
# filling data of laptop no. 407
# Finished filling in: 1.1800000038419967e-05
# *******************************
#
# filling data of laptop no. 408
# Finished filling in: 1.3200000012147939e-05
# *******************************
#
# filling data of laptop no. 409
# Finished filling in: 1.1900000117748277e-05
# *******************************
#
# filling data of laptop no. 410
# Finished filling in: 1.2900000001536682e-05
# *******************************
#
# filling data of laptop no. 411
# Finished filling in: 1.2599999990925426e-05
# *******************************
#
# filling data of laptop no. 412
# Finished filling in: 1.1999999969702912e-05
# *******************************
#
# filling data of laptop no. 413
# Finished filling in: 1.2599999990925426e-05
# *******************************
#
# filling data of laptop no. 414
# Finished filling in: 1.3099999932819628e-05
# *******************************
#
# filling data of laptop no. 415
# Finished filling in: 1.2599999990925426e-05
# *******************************
#
# filling data of laptop no. 416
# Finished filling in: 3.500000002532033e-05
# *******************************
#
# filling data of laptop no. 417
# Finished filling in: 1.13999999484804e-05
# *******************************
#
# filling data of laptop no. 418
# Finished filling in: 1.2599999990925426e-05
# *******************************
#
# filling data of laptop no. 419
# Finished filling in: 1.1999999969702912e-05
# *******************************
#
# filling data of laptop no. 420
# Finished filling in: 1.13999999484804e-05
# *******************************
#
# filling data of laptop no. 421
# Finished filling in: 1.1800000038419967e-05
# *******************************
#
# filling data of laptop no. 422
# Finished filling in: 1.2199999900985858e-05
# *******************************
#
# filling data of laptop no. 423
# Finished filling in: 1.150000002780871e-05
# *******************************
#
# filling data of laptop no. 424
# Finished filling in: 1.1999999969702912e-05
# *******************************
#
# filling data of laptop no. 425
# Finished filling in: 1.1200000017197453e-05
# *******************************
#
# filling data of laptop no. 426
# Finished filling in: 1.1800000038419967e-05
# *******************************
#
# filling data of laptop no. 427
# Finished filling in: 1.1100000165242818e-05
# *******************************
#
# filling data of laptop no. 428
# Finished filling in: 1.1699999959091656e-05
# *******************************
#
# filling data of laptop no. 429
# Finished filling in: 1.2900000001536682e-05
# *******************************
#
# filling data of laptop no. 430
# Finished filling in: 1.160000010713702e-05
# *******************************
#
# filling data of laptop no. 431
# Finished filling in: 1.3700000181415817e-05
# *******************************
#
# filling data of laptop no. 432
# Finished filling in: 1.2199999900985858e-05
# *******************************
#
# filling data of laptop no. 433
# Finished filling in: 3.930000002583256e-05
# *******************************
#
# filling data of laptop no. 434
# Finished filling in: 1.1000000085914508e-05
# *******************************
#
# filling data of laptop no. 435
# Finished filling in: 2.199999994445534e-05
# *******************************
#
# filling data of laptop no. 436
# Finished filling in: 1.2200000128359534e-05
# *******************************
#
# filling data of laptop no. 437
# Finished filling in: 1.330000009147625e-05
# *******************************
#
# filling data of laptop no. 438
# Finished filling in: 1.1699999959091656e-05
# *******************************
#
# filling data of laptop no. 439
# Finished filling in: 1.1699999959091656e-05
# *******************************
#
# filling data of laptop no. 440
# Finished filling in: 3.7199999951553764e-05
# *******************************
#
# filling data of laptop no. 441
# Finished filling in: 1.13999999484804e-05
# *******************************
#
# filling data of laptop no. 442
# Finished filling in: 1.1899999890374602e-05
# *******************************
#
# filling data of laptop no. 443
# Finished filling in: 1.1999999969702912e-05
# *******************************
#
# filling data of laptop no. 444
# Finished filling in: 1.2799999922208372e-05
# *******************************
#
# filling data of laptop no. 445
# Finished filling in: 1.4700000065204222e-05
# *******************************
#
# filling data of laptop no. 446
# Finished filling in: 1.2900000001536682e-05
# *******************************
#
# filling data of laptop no. 447
# Finished filling in: 1.5999999959603883e-05
# *******************************
#
# filling data of laptop no. 448
# Finished filling in: 5.329999999048596e-05
# *******************************
#
# filling data of laptop no. 449
# Finished filling in: 7.209999989754579e-05
# *******************************
#
# ...
# *******************************
#
# filling data of laptop no. 836
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 837
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 838
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 839
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 840
# Finished filling in: 6.499999926745659e-06
# *******************************
#
# filling data of laptop no. 841
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 842
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 843
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 844
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 845
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 846
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 847
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 848
# Finished filling in: 6.199999916134402e-06
# *******************************
#
# filling data of laptop no. 849
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 850
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 851
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 852
# Finished filling in: 5.900000132896821e-06
# *******************************
#
# filling data of laptop no. 853
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 854
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 855
# Finished filling in: 6.200000143508078e-06
# *******************************
#
# filling data of laptop no. 856
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 857
# Finished filling in: 1.13999999484804e-05
# *******************************
#
# filling data of laptop no. 858
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 859
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 860
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 861
# Finished filling in: 2.669999980753346e-05
# *******************************
#
# filling data of laptop no. 862
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 863
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 864
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 865
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 866
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 867
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 868
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 869
# Finished filling in: 6.500000154119334e-06
# *******************************
#
# filling data of laptop no. 870
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 871
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 872
# Finished filling in: 1.3699999954042141e-05
# *******************************
#
# filling data of laptop no. 873
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 874
# Finished filling in: 1.2100000049031223e-05
# *******************************
#
# filling data of laptop no. 875
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 876
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 877
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 878
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 879
# Finished filling in: 5.499999815583578e-06
# *******************************
#
# filling data of laptop no. 880
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 881
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 882
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 883
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 884
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 885
# Finished filling in: 5.199999804972322e-06
# *******************************
#
# filling data of laptop no. 886
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 887
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 888
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 889
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 890
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 891
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 892
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 893
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 894
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 895
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 896
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 897
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 898
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 899
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 900
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 901
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 902
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 903
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 904
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 905
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 906
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 907
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 908
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 909
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 910
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 911
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 912
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 913
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 914
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 915
# Finished filling in: 2.8299999939918052e-05
# *******************************
#
# filling data of laptop no. 916
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 917
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 918
# Finished filling in: 5.199999804972322e-06
# *******************************
#
# filling data of laptop no. 919
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 920
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 921
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 922
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 923
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 924
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 925
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 926
# Finished filling in: 5.6000001222855644e-06
# *******************************
#
# filling data of laptop no. 927
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 928
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 929
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 930
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 931
# Finished filling in: 5.200000032345997e-06
# *******************************
#
# filling data of laptop no. 932
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 933
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 934
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 935
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 936
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 937
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 938
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 939
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 940
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 941
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 942
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 943
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 944
# Finished filling in: 6.0999998368060915e-06
# *******************************
#
# filling data of laptop no. 945
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 946
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 947
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 948
# Finished filling in: 5.199999804972322e-06
# *******************************
#
# filling data of laptop no. 949
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 950
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 951
# Finished filling in: 5.999999984851456e-06
# *******************************
#
# filling data of laptop no. 952
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 953
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 954
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 955
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 956
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 957
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 958
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 959
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 960
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 961
# Finished filling in: 5.599999894911889e-06
# *******************************
#
# filling data of laptop no. 962
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 963
# Finished filling in: 5.80000005356851e-06
# *******************************
#
# filling data of laptop no. 964
# Finished filling in: 5.299999884300632e-06
# *******************************
#
# filling data of laptop no. 965
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 966
# Finished filling in: 5.6999999742402e-06
# *******************************
#
# filling data of laptop no. 967
# Finished filling in: 5.799999826194835e-06
# *******************************
#
# filling data of laptop no. 968
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 969
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 970
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 971
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 972
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 973
# Finished filling in: 4.930000000058499e-05
# *******************************
#
# filling data of laptop no. 974
# Finished filling in: 5.8999999055231456e-06
# *******************************
#
# filling data of laptop no. 975
# Finished filling in: 5.4000001910026185e-06
# *******************************
#
# filling data of laptop no. 976
# Finished filling in: 5.500000042957254e-06
# *******************************
#
# filling data of laptop no. 977
# Finished filling in: 5.0999999530176865e-06
# *******************************
#
# filling data of laptop no. 978
# Finished filling in: 5.399999963628943e-06
# *******************************
#
# filling data of laptop no. 979
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 980
# Finished filling in: 5.700000201613875e-06
# *******************************
#
# filling data of laptop no. 981
# Finished filling in: 5.300000111674308e-06
# *******************************
#
# filling data of laptop no. 982
# Finished filling in: 6.100000064179767e-06
# *******************************
#
# filling data of laptop no. 983
# Finished filling in: 5.199999804972322e-06
# *******************************
#
# filling data of laptop no. 984
# Finished filling in: 6.199999916134402e-06
# Script executed in 0.014179100000092149

# %%
# Create the DataFrame

import pandas as pd
laptops_df = pd.DataFrame({'Name': name_lst,
    'Price': price_lst,
    'Type': type_lst,
    'Processor Brand': processor_brand_lst,
    'Processor Name': processor_name_lst,
    'Processor Generation': processor_gen_lst,
    'SSD': ssd_lst,
    'SSD Capacity': ssd_cap_lst,
    'HDD Capacity': hdd_cap_lst,
    'EMMC Storage Capacity': emmc_lst,
    'RAM': ram_lst,
    'Clock Speed': clk_speed_lst,
    'Graphic Processor': gpu_lst,
    'Operating System': os_lst,
    'Touchscreen': touchscreen_lst,
    'Screen Size': screen_size_lst,
    'Screen Resolution': screen_res_lst,
    'Screen Type': screen_type_lst,
    'Weight': weight_lst,
    'Fingerprint Sensor': fp_sensor_lst,
    'Backlit Keyboard': key_light_lst
})

# %%
laptops_df.sample(5)
# Out:
#                                                   Name    Price  \
# 706  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...  ₹35,990
# 912  HP Intel Core i3 10th Gen - (8 GB/512 GB SSD/W...  ₹38,990
# 793  Acer Aspire 3 Pentium Quad Core - (4 GB/256 GB...  ₹37,990
# 941  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...  ₹35,990
# 120  Primebook 4G Android Based MediaTek MT8788 - (...  ₹13,990
#
#                       Type Processor Brand     Processor Name  \
# 706  Thin and Light Laptop           Intel            Core i3
# 912  Thin and Light Laptop           Intel            Core i3
# 793  Thin and Light Laptop           Intel  Pentium Quad Core
# 941  Thin and Light Laptop           Intel            Core i3
# 120  Thin and Light Laptop        MediaTek    MediaTek MT8788
#
#     Processor Generation  SSD SSD Capacity HDD Capacity EMMC Storage Capacity  \
# 706             11th Gen  Yes       512 GB            0                     0
# 912             10th Gen  Yes       512 GB            0                     0
# 793                  NaN  Yes       256 GB            0                     0
# 941             11th Gen  Yes       512 GB            0                     0
# 120                  NaN   No            0            0                 64 GB
#
#      ...                                        Clock Speed  \
# 706  ...  Base Clock 1.70 Ghz, Max Turbo Boost Frequency...
# 912  ...              2.1 GHz with Turbo Boost Upto 4.1 GHz
# 793  ...                             2.0 GHz up to 3.30 GHz
# 941  ...  Base Clock 1.70 Ghz, Max Turbo Boost Frequency...
# 120  ...                        Max Frequency Up to 2.0 GHz
#
#                     Graphic Processor Operating System Touchscreen  \
# 706              Intel Integrated UHD  Windows 11 Home          No
# 912              Intel Integrated UHD  Windows 10 Home          No
# 793              Intel Integrated UHD  Windows 11 Home          No
# 941              Intel Integrated UHD  Windows 11 Home          No
# 120  MediaTek Integrated ARM Mali G72         Prime OS          No
#
#               Screen Size  Screen Resolution  \
# 706    35.56 cm (14 Inch)  1920 x 1080 Pixel
# 912  39.62 cm (15.6 inch)  1920 x 1080 Pixel
# 793    35.56 cm (14 Inch)   1366 x 768 Pixel
# 941    35.56 cm (14 Inch)  1920 x 1080 Pixel
# 120  29.46 cm (11.6 Inch)  1366 x 768 Pixels
#
#                                            Screen Type    Weight  \
# 706            Full HD TN 250nits Anti-glare, 45% NTSC   1.41 Kg
# 912  Full HD LED Backlit Anti-glare Micro-edge Disp...   1.74 kg
# 793  HD resolution, Acer ComfyViewTM LED-backlit TF...   1.45 Kg
# 941            Full HD TN 250nits Anti-glare, 45% NTSC   1.41 Kg
# 120                                             HD IPS  1.065 Kg
#
#     Fingerprint Sensor Backlit Keyboard
# 706                 No               No
# 912                 No               No
# 793                 No              Yes
# 941                 No               No
# 120                 No               No
#
# [5 rows x 21 columns]

# %%
laptops_df.shape
# Out:
# (984, 21)

# %%
laptops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   984 non-null    object
#  1   Price                  984 non-null    object
#  2   Type                   984 non-null    object
#  3   Processor Brand        984 non-null    object
#  4   Processor Name         984 non-null    object
#  5   Processor Generation   569 non-null    object
#  6   SSD                    984 non-null    object
#  7   SSD Capacity           984 non-null    object
#  8   HDD Capacity           984 non-null    object
#  9   EMMC Storage Capacity  984 non-null    object
#  10  RAM                    984 non-null    object
#  11  Clock Speed            848 non-null    object
#  12  Graphic Processor      984 non-null    object
#  13  Operating System       984 non-null    object
#  14  Touchscreen            984 non-null    object
#  15  Screen Size            984 non-null    object
#  16  Screen Resolution      984 non-null    object
#  17  Screen Type            918 non-null    object
#  18  Weight                 942 non-null    object
#  19  Fingerprint Sensor     984 non-null    object
#  20  Backlit Keyboard       984 non-null    object
# dtypes: object(21)
# memory usage: 161.6+ KB

# %% [markdown]
# #### Export the laptops_df to csv or excel file

# %%
#laptops_df.to_csv("Laptops_data.csv", index=False)
laptops_df.to_excel("Laptops_data.xlsx", index=False)
